# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("new_insurance_data (1).csv")

# %%
data.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# ...

# %%
data.shape
# Out:
# (1338, 13)

# %%
data.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1329.000000  1335.000000  1333.000000   1324.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      14.034818     6.101690     1.201856  15617.288337
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.302500     0.000000  20768.860390
# 50%      39.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.687500     2.000000  45052.331957
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1332.000000  1.335000e+03          1.334000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.467723  9.188612e+04          2.669305e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.471995e+05          4.077633e+06
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
sns.distplot(data['age'])
plt.title('distribution of age')
plt.xlabel('age')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gandh\AppData\Local\Temp\ipykernel_14272\1849679590.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'])

# %%
sns.distplot(x=data['bmi'])
plt.xlabel('bmi')
plt.ylabel('count')
plt.title('distribution of bmi')
plt.show()
# Out:
# C:\Users\gandh\AppData\Local\Temp\ipykernel_14272\2594255621.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['bmi'])

# %%
plt.subplots(1,3,figsize=(10,7))
plt.subplot(1,3,1)
sns.countplot(x=data['children'])
plt.xlabel('no. of children')
plt.ylabel('count')

plt.subplot(1,3,2)
sns.histplot(x = data['children'])
plt.xlabel('no. of children')
plt.ylabel('count')

plt.subplot(1,3,3)
sns.distplot(x=data['children'])
plt.xlabel('no. of children')
plt.ylabel('count')

plt.subplots_adjust(hspace=0.5,wspace=0.5)
plt.show()
# Out:
# C:\Users\gandh\AppData\Local\Temp\ipykernel_14272\1508902183.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['children'])

# %%
sns.distplot(data['Claim_Amount'])
plt.xlabel('claim amount')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gandh\AppData\Local\Temp\ipykernel_14272\847449410.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Claim_Amount'])

# %%
sns.distplot(data['past_consultations'])
plt.xlabel('number of past consultations')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\gandh\AppData\Local\Temp\ipykernel_14272\523726824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['past_consultations'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['smoker'] = le.fit_transform(data['smoker'])
data['smoker'] = data['smoker'].astype(int)

data['sex'] = le.fit_transform(data['sex'])
data['sex'] = data['sex'].astype(int)

data['region'] = le.fit_transform(data['region'])
data['region'] = data['region'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   int32
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   int32
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   int32
# ...

# %%
data.isna().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
data['age'] = data['age'].fillna(data['age'].mean())
data['bmi'] = data['bmi'].fillna(data['bmi'].mean())
data['children'] = data['children'].fillna(data['children'].median())
data['Claim_Amount'] = data['Claim_Amount'].fillna(data['Claim_Amount'].mean())
data['past_consultations'] = data['past_consultations'].fillna(data['past_consultations'].mean())
data['num_of_steps'] = data['num_of_steps'].fillna(data['num_of_steps'].mean())
data['Hospital_expenditure'] = data['Hospital_expenditure'].fillna(data['Hospital_expenditure'].median())
data['NUmber_of_past_hospitalizations'] = data['NUmber_of_past_hospitalizations'].fillna(data['NUmber_of_past_hospitalizations'].median())
data['Anual_Salary'] = data['Anual_Salary'].fillna(data['Anual_Salary'].median())

# %%
data.isna().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
correlation=data.corr()
correlation
# Out:
#                                       age       sex       bmi  children  \
# age                              1.000000 -0.019105  0.112161  0.041616
# sex                             -0.019105  1.000000  0.045170  0.018533
# bmi                              0.112161  0.045170  1.000000  0.007755
# children                         0.041616  0.018533  0.007755  1.000000
# smoker                          -0.028868  0.076185  0.003610  0.009608
# Claim_Amount                     0.122828 -0.003884  0.093313  0.041502
# past_consultations               0.168311  0.050403  0.130667  0.054832
# num_of_steps                     0.512985  0.010342  0.135903  0.163487
# Hospital_expenditure             0.137146  0.069940  0.256892  0.025315
# NUmber_of_past_hospitalizations  0.359434  0.000214  0.137043  0.185546
# Anual_Salary                     0.163392  0.072702  0.241505  0.041260
# region                           0.004659  0.004588  0.158261  0.015011
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation,annot=True,cmap='Blues',linewidth=1)
plt.show()

# %%
x=data.drop(['charges'],axis=1)
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test,predicted)
# Out:
# 0.972292983018323
